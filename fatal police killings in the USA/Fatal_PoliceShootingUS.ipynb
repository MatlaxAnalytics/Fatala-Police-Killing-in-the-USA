# %%
#Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.filterwarnings ("ignore")

# %%
#Loading the dataset

# %%
shootings_df = pd.read_excel ("C:/Users/brynm/Desktop/BRYN/Portfolios And Projects/Fatal Police Shootings in the USA/data.xls")
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
shootings_df.head()
# Out:
#    id                name        date   manner_of_death       armed  age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun   53
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun   47
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed   23
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon   32
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun   39
#
#   gender      race           city state  ...  threat_level         flee  \
# 0   Male     Asian        Shelton    WA  ...        attack  Not fleeing
# 1   Male     White          Aloha    OR  ...        attack  Not fleeing
# 2   Male  Hispanic        Wichita    KS  ...         other  Not fleeing
# 3   Male     White  San Francisco    CA  ...        attack  Not fleeing
# 4   Male  Hispanic          Evans    CO  ...        attack  Not fleeing
#
#   body_camera  longitude  latitude  is_geocoding_exact  day  month  year  \
# ...

# %%
shootings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7662 entries, 0 to 7661
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       7662 non-null   int64
#  1   name                     7662 non-null   object
#  2   date                     7662 non-null   object
#  3   manner_of_death          7662 non-null   object
#  4   armed                    7662 non-null   object
#  5   age                      7662 non-null   int64
#  6   gender                   7662 non-null   object
#  7   race                     7662 non-null   object
#  8   city                     7662 non-null   object
#  9   state                    7662 non-null   object
#  10  signs_of_mental_illness  7662 non-null   bool
#  11  threat_level             7662 non-null   object
#  12  flee                     7662 non-null   object
#  13  body_camera              7662 non-null   bool
# ...

# %%
shootings_df.describe()
# Out:
#                 id          age    longitude     latitude          day  \
# count  7662.000000  7662.000000  6832.000000  6832.000000  7662.000000
# mean   4232.256983    34.904203   -97.056950    36.669658    15.572566
# std    2392.923808    15.360693    16.597978     5.394650     8.783678
# min       3.000000     0.000000  -160.007000    19.498000     1.000000
# 25%    2148.250000    26.000000  -112.042250    33.480000     8.000000
# 50%    4256.500000    34.000000   -94.242000    36.095500    15.500000
# 75%    6306.750000    45.000000   -83.083250    40.025250    23.000000
# max    8336.000000    92.000000   -67.867000    71.301000    31.000000
#
#              month         year
# count  7662.000000  7662.000000
# mean      6.253981  2018.388019
# std       3.427428     2.220439
# min       1.000000  2015.000000
# 25%       3.000000  2016.000000
# 50%       6.000000  2018.000000
# 75%       9.000000  2020.000000
# max      12.000000  2022.000000

# %%
shootings_df.isna().sum()
# Out:
# id                           0
# name                         0
# date                         0
# manner_of_death              0
# armed                        0
# age                          0
# gender                       0
# race                         0
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                         0
# body_camera                  0
# longitude                  830
# latitude                   830
# is_geocoding_exact           0
# day                          0
# month                        0
# year                         0
# monthname                    0
# dtype: int64

# %%
shootings_df.replace(np.nan, "0", inplace = True)

# %%
shootings_df.isna().sum()
# Out:
# id                         0
# name                       0
# date                       0
# manner_of_death            0
# armed                      0
# age                        0
# gender                     0
# race                       0
# city                       0
# state                      0
# signs_of_mental_illness    0
# threat_level               0
# flee                       0
# body_camera                0
# longitude                  0
# latitude                   0
# is_geocoding_exact         0
# day                        0
# month                      0
# year                       0
# monthname                  0
# dtype: int64

# %%
shootings_df.shape
# Out:
# (7662, 21)

# %%
shootings_df.columns
# Out:
# Index(['id', 'name', 'date', 'manner_of_death', 'armed', 'age', 'gender',
#        'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level',
#        'flee', 'body_camera', 'longitude', 'latitude', 'is_geocoding_exact',
#        'day', 'month', 'year', 'monthname'],
#       dtype='object')

# %%
shootings_df['year'].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022], dtype=int64)

# %%
print(shootings_df.duplicated().sum())
# Out:
# 0

# %%
shootings_df['year'].value_counts()
# Out:
# 2021    1055
# 2020    1020
# 2019     999
# 2015     994
# 2018     993
# 2017     981
# 2016     958
# 2022     662
# Name: year, dtype: int64

# %%
shootings_df['monthname'].value_counts()
# Out:
# March        737
# June         686
# January      680
# February     678
# July         674
# May          662
# April        649
# August       633
# October      607
# December     595
# November     554
# September    507
# Name: monthname, dtype: int64

# %%
shootings_df['gender'].value_counts()
# Out:
# Male      7300
# Female     344
# Other       18
# Name: gender, dtype: int64

# %%
shootings_df['race'].value_counts()
# Out:
# White              3181
# Black              1674
# Unknown            1424
# Hispanic           1127
# Asian               112
# Native American      97
# Other                47
# Name: race, dtype: int64

# %%
#Total Killings by manner of death
shootings_df['manner_of_death'].value_counts()
# Out:
# shot                7323
# shot and Tasered     339
# Name: manner_of_death, dtype: int64

# %%
shootings_df2 = shootings_df[shootings_df['year'] > 2019]

# %%
shootings_df2
# Out:
#         id                            name        date   manner_of_death  \
# 4925  5344               Derrick A. Elseth  2020-01-01              shot
# 4926  5347     Teddy James Maverick Varner  2020-01-01              shot
# 4927  5403  Gerardo Antonio Conchas-Bustas  2020-01-01              shot
# 4928  5342              Gabriel Strickland  2020-01-01  shot and Tasered
# 4929  5339            Jeffery Dale Millsap  2020-01-02              shot
# ...    ...                             ...         ...               ...
# 7657  8333                    Tyler Mendez  2022-08-11              shot
# 7658  8335                     Byron Hayes  2022-08-11              shot
# 7659  8332                         Unknown  2022-08-12              shot
# 7660  8334                         Unknown  2022-08-12              shot
# 7661  8336                  Michael Ahrens  2022-08-14              shot
#
#            armed  age gender     race             city state  ...  \
# ...

# %%
shootings_df3 = shootings_df2[shootings_df2['race'] == 'Black']
shootings_df3
# Out:
#         id                   name        date   manner_of_death    armed  age  \
# 4931  5349   Jamari Daiwon Tarver  2020-01-02              shot  vehicle   26
# 4935  5341            Tyree Davis  2020-01-04  shot and Tasered    knife   25
# 4937  5335           Kwamae Jones  2020-01-05              shot      gun   17
# 4938  5336     Brandon D. Roberts  2020-01-05              shot    knife   27
# 4940  5352             Miciah Lee  2020-01-05              shot      gun   18
# ...    ...                    ...         ...               ...      ...  ...
# 7478  8135  Jerome Lavon Connelly  2022-06-12              shot      gun   35
# 7493  8153       Derrick D. Clark  2022-06-18              shot      gun   24
# 7525  8185         Jayland Walker  2022-06-27              shot  unarmed   25
# 7550  8217      Reginald Humphrey  2022-07-05              shot      gun   31
# 7585  8258  Robert Marquise Adams  2022-07-16              shot      gun   23
#
# ...

# %%
shootings_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 479 entries, 4931 to 7585
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       479 non-null    int64
#  1   name                     479 non-null    object
#  2   date                     479 non-null    object
#  3   manner_of_death          479 non-null    object
#  4   armed                    479 non-null    object
#  5   age                      479 non-null    int64
#  6   gender                   479 non-null    object
#  7   race                     479 non-null    object
#  8   city                     479 non-null    object
#  9   state                    479 non-null    object
#  10  signs_of_mental_illness  479 non-null    bool
#  11  threat_level             479 non-null    object
#  12  flee                     479 non-null    object
#  13  body_camera              479 non-null    bool
# ...

# %%
shootings_df['race'].unique()
# Out:
# array(['Asian', 'White', 'Hispanic', 'Black', 'Other', 'Unknown',
#        'Native American'], dtype=object)

# %%
shootings_df['race'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (13,6))
data = shootings_df['gender'].value_counts()
labels = ['Male', 'Female', 'Other']
color = sns.color_palette('Set2')
plt.pie(data,labels = labels,colors = color, autopct = '%.1f%%')
plt.show()
